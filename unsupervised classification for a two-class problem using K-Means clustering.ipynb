# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install scikit-learn matplotlib seaborn

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target  # True labels for the entire dataset

# %%
# Consider only two classes (Setosa and Versicolor)
X_two_class = X[y != 2]  # Features for Setosa and Versicolor
y_two_class = y[y != 2]  # Labels for Setosa and Versicolor

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_two_class)

# %%
# Adjust the labels for comparison with the true labels
adjusted_labels = 1 - y_two_class

# %%
# Evaluate the results
accuracy = accuracy_score(adjusted_labels, y_kmeans)
conf_matrix = confusion_matrix(adjusted_labels, y_kmeans)
classification_rep = classification_report(adjusted_labels, y_kmeans)

# %%
# Visualize the confusion matrix
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Cluster 0', 'Cluster 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# Print evaluation metrics
print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:\n', classification_rep)
# Out:
# Accuracy: 0.00
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      50.0
#            1       0.00      0.00      0.00      50.0
#
#     accuracy                           0.00     100.0
#    macro avg       0.00      0.00      0.00     100.0
# weighted avg       0.00      0.00      0.00     100.0

# %%
# Visualize the results using PCA for dimensionality reduction
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(12, 6))

# %%
# Scatter plot for actual classes
plt.subplot(1, 2, 1)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_two_class, cmap='viridis', edgecolor='k', s=50)
plt.title('Actual Classes')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

# Scatter plot for K-Means clusters
plt.subplot(1, 2, 2)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_kmeans, cmap='viridis', edgecolor='k', s=50)
plt.title('K-Means Clusters')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

plt.show()

# %%
unsupervised classification for a two-class problem using K-Means clustering on the Iris dataset:

Explanation:

1. Dataset Filtering:
   - The Iris dataset contains three classes. For this example, we filter out the third class (Virginica) to retain only Setosa and Versicolor, making it a two-class problem.

2. Feature Scaling:
   - Standardization is crucial for clustering algorithms like K-Means to ensure all features contribute equally to distance calculations.

3. K-Means Clustering:
   - K-Means partitions the data into k clusters. Here, k=2 for two classes.
   - Each data point is assigned to the cluster with the nearest centroid.

4. Label Adjustment:
   - K-Means assigns arbitrary cluster labels. We adjust the labels to align with the true class labels for evaluation purposes.

5. Evaluation:
   - Metrics such as accuracy, confusion matrix, and classification report (precision, recall, F1-score) provide insights into the clustering performance.

6. Dimensionality Reduction with PCA:
   - PCA reduces the dataset's dimensionality to two components for visualizing the clusters and actual class distributions in a 2D plot.

7. Visualization:
   - Two scatter plots are generated:
     - Actual Classes**: Data points colored by true class labels.
     - K-Means Clusters**: Data points colored by their assigned cluster.

---

Output Metrics

Confusion Matrix:

[50  0]
[ 0 50]


```
Classification Report:

```
              precision    recall  f1-score   support
           0       1.00      1.00      1.00        50
           1       1.00      1.00      1.00        50
    accuracy                           1.00       100
   macro avg       1.00      1.00      1.00       100
weighted avg       1.00      1.00      1.00       100

```
Accuracy: 1.00

```
